# %%
import pandas as pd
from os import listdir
from os import makedirs
from os.path import isfile, join, isdir

fb_dir_path = "preprocessed/fb/"
google_dir_path = "preprocessed/google/"
if not isdir('preprocessed'):
    makedirs(fb_dir_path)
    makedirs(google_dir_path)

# %%
fb_adviser = pd.read_csv("FacebookAdLibraryReport_2020-06-10_US_last_90_days/FacebookAdLibraryReport_2020-06-10_US_last_90_days_advertisers.csv")

# %%
fb_adviser.head(5)
# Out:
#            Page ID           Page Name  \
# 0     202626512363  U.S. Census Bureau
# 1       7860876103           Joe Biden
# 2  156968474833352    Stop Republicans
# 3     153080620724     Donald J. Trump
# 4     153080620724     Donald J. Trump
#
#                                  Disclaimer Amount Spent (USD)  \
# 0                        U.S. Census Bureau           15359523
# 1                       BIDEN FOR PRESIDENT           14320700
# 2                          Stop Republicans            7917760
# 3  TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE            5577049
# 4       DONALD J. TRUMP FOR PRESIDENT, INC.            3843158
#
#    Number of Ads in Library
# 0                      2786
# 1                      7092
# 2                       796
# 3                     51986
# 4                     32967

# %%
campaigns = ['Joe Biden', 'Donald J. Trump', 'Democratic Governors Association (DGA)', 'Republican Governors Association (RGA)']
fb_campaign_adviser = fb_adviser[fb_adviser['Page Name'].isin(campaigns)]
fb_campaign_adviser.to_csv(fb_dir_path + 'fb_campaign_advisers.csv', index = False)

# %%
# ================== region ===================
fb_ca_adviser = pd.read_csv("FacebookAdLibraryReport_2020-06-10_US_last_90_days/regions/FacebookAdLibraryReport_2020-06-10_US_last_90_days_California.csv")
fb_ca_adviser.head(5)
# Out:
#            Page ID                               Page Name  \
# 0       7860876103                               Joe Biden
# 1     202626512363                      U.S. Census Bureau
# 2  156968474833352                        Stop Republicans
# 3      94999047581  California Department of Public Health
# 4     153080620724                         Donald J. Trump
#
#                                  Disclaimer Amount Spent (USD)
# 0                       BIDEN FOR PRESIDENT            2125082
# 1                        U.S. Census Bureau            2061074
# 2                          Stop Republicans            1167971
# 3    California Department of Public Health            1036936
# 4  TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE             475852

# %%
dir_path = "FacebookAdLibraryReport_2020-06-10_US_last_90_days/regions/"
files = [f for f in listdir(dir_path) if isfile(join(dir_path, f))]

# %%
fb_regoin_advisers = []
for file_name in files:
    region = file_name.split('_')[-1][:-4]
    fb_region_advisor = pd.read_csv(dir_path + file_name)
    fb_region_advisor = fb_region_advisor[fb_region_advisor['Page Name'].isin(campaigns)]
    fb_region_advisor.to_csv(fb_dir_path + "fb_campaign_advisers_" + region + ".csv", index = False)

# %%
# ====== google ===== 
# democratic national committee not in the dataset, so i just filter based on Regions
# select rows only with Regions == 'US'
google_advertiser_stats = pd.read_csv("google-political-ads-transparency-bundle/google-political-ads-advertiser-stats.csv")
google_advertiser_stats = google_advertiser_stats.iloc[:,:7]
google_advertiser_stats = google_advertiser_stats[google_advertiser_stats['Regions'] == 'US']
google_advertiser_stats = google_advertiser_stats.sort_values(by = 'Spend_USD', ascending = False)
google_advertiser_stats.to_csv(google_dir_path + "google-political-ads-advertiser-stats.csv", index = False)
google_advertiser_stats.head(5)
# Out:
#              Advertiser_ID                           Advertiser_Name  \
# 1795  AR458000056721604608                   MIKE BLOOMBERG 2020 INC
# 1949  AR488306308034854912  TRUMP MAKE AMERICA GREAT AGAIN COMMITTEE
# 1663  AR432709227698454528                           TOM STEYER 2020
# 1424  AR383080296477622272                               BERNIE 2020
# 27    AR105500339708362752       DONALD J. TRUMP FOR PRESIDENT, INC.
#
#         Public_IDs_List Regions   Elections  Total_Creatives  Spend_USD
# 1795  EIN ID 84-3637738      US  US-Federal            64243   62266300
# 1949   FEC ID C00618371      US  US-Federal            35024   17329500
# 1663  EIN ID 84-2308418      US  US-Federal             1258    8872100
# 1424   FEC ID C00696948      US  US-Federal              962    8711100
# 27     FEC ID C00580100      US  US-Federal             6705    7318500

# %%
# names = google_advertiser_stats['Advertiser_Name'].unique()
# for i in names:
#     i = i.lower()
#     if 'trump' in i or 'joe' in i or 'democratic' in i or 'republican' in i:
#         print(i)

# %%
# =============
# democratic national committee not in the dataset
# filter Advertiser_Name
advertisers = ["republican national committee", "donald j. trump for president, inc.", \
               "dnc services corp./dem. nat'l committee", "BIDEN FOR PRESIDENT"]
google_advertiser_weekly_spend = pd.read_csv("google-political-ads-transparency-bundle/google-political-ads-advertiser-weekly-spend.csv")
google_advertiser_weekly_spend = google_advertiser_weekly_spend.iloc[:,:5]
google_advertiser_weekly_spend = google_advertiser_weekly_spend.sort_values(by = 'Spend_USD', ascending = False)
google_advertiser_weekly_spend = google_advertiser_weekly_spend[google_advertiser_weekly_spend.Advertiser_Name.isin(advertisers)]
google_advertiser_weekly_spend.to_csv(google_dir_path + "google-political-ads-advertiser-weekly-spend.csv", index = False)
google_advertiser_weekly_spend.head(10)
# Out:
#               Advertiser_ID      Advertiser_Name   Election_Cycle  \
# 28303   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28309   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28258   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28302   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28310   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28314   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 633    AR108481940364984320  BIDEN FOR PRESIDENT  US-Federal-2018
# 28313   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28311   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
# 28304   AR55282894888763392  BIDEN FOR PRESIDENT  US-Federal-2018
#
#       Week_Start_Date  Spend_USD
# 28303      2020-03-01    1728200
# 28309      2020-04-12     388200
# 28258      2019-04-21     362900
# 28302      2020-02-23     319300
# 28310      2020-04-19     305500
# 28314      2020-05-17     278600
# 633        2020-03-08     260300
# 28313      2020-05-10     233200
# 28311      2020-04-26     232500
# 28304      2020-03-08     232300

# %%
# names = google_advertiser_weekly_spend.Advertiser_Name.unique()
# for i in names:
#     i = i.lower()
#     if 'trump' in i or 'joe' in i or "nat'l" in i or 'republican' in i:
#         print(i)

# %%
# ================
# democratic national committee not in the dataset, so i just filter based on Regions
# select rows only with Regions == 'US'
google_creative_stats = pd.read_csv("google-political-ads-transparency-bundle/google-political-ads-creative-stats.csv")
# Out:
# C:\Users\clair\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
google_creative_stats = google_creative_stats.iloc[:,:20]
google_creative_stats = google_creative_stats[google_creative_stats.Regions == 'US']
google_creative_stats.to_csv(google_dir_path + "google-political-ads-creative-stats.csv", index = False)
google_creative_stats.head()
# Out:
#                   Ad_ID                                             Ad_URL  \
# 0   CR49101990273220608  https://transparencyreport.google.com/politica...
# 1  CR307705063541833728  https://transparencyreport.google.com/politica...
# 2  CR463105089209368576  https://transparencyreport.google.com/politica...
# 3  CR483300918788358144  https://transparencyreport.google.com/politica...
# 4  CR539595914130489344  https://transparencyreport.google.com/politica...
#
#   Ad_Type Regions         Advertiser_ID            Advertiser_Name  \
# 0    Text      US  AR100207290732249088    FRIENDS OF SUZY GLOWIAK
# 1   Image      US  AR100293190078169088  DYLAN BILLINGS FOR SENATE
# 2    Text      US   AR10057920054034432       ARCHERD FOR CONGRESS
# 3    Text      US   AR10057920054034432       ARCHERD FOR CONGRESS
# 4    Text      US   AR10057920054034432       ARCHERD FOR CONGRESS
#
#    Ad_Campaigns_List Date_Range_Start Date_Range_End  Num_of_Days Impressions  \
# 0                NaN       2018-09-22     2018-11-06           46       ≤ 10k
# 1                NaN       2019-09-17     2019-09-18            2    10k-100k
# 2                NaN       2020-01-07     2020-03-03           55       ≤ 10k
# 3                NaN       2020-01-07     2020-03-03           55    10k-100k
# 4                NaN       2020-01-07     2020-03-03           55    10k-100k
#
#   Spend_USD First_Served_Timestamp Last_Served_Timestamp Age_Targeting  \
# 0    100-1k   2018-09-22T07:00:00Z  2018-11-06T08:00:00Z  Not targeted
# 1     ≤ 100   2019-09-17T07:00:00Z  2019-09-18T07:00:00Z  Not targeted
# 2    100-1k   2020-01-08T05:00:00Z  2020-03-03T11:15:00Z  Not targeted
# 3    100-1k   2020-01-08T05:15:00Z  2020-03-03T11:30:00Z  Not targeted
# 4    100-1k   2020-01-08T05:15:00Z  2020-03-03T11:30:00Z  Not targeted
#
#   Gender_Targeting                             Geo_Targeting_Included  \
# 0     Not targeted  60126, 60137, 60148, 60181, 60187, 60189, 6051...
# 1     Not targeted                                           Oklahoma
# 2     Not targeted  28090, 28167, 28601, 28602, 28605, 28606, 2861...
# 3     Not targeted  28090, 28167, 28601, 28602, 28605, 28606, 2861...
# 4     Not targeted  28090, 28167, 28601, 28602, 28605, 28606, 2861...
#
#   Geo_Targeting_Excluded  Spend_Range_Min_USD  Spend_Range_Max_USD
# 0           Not targeted                  100               1000.0
# 1           Not targeted                    0                100.0
# 2           Not targeted                  100               1000.0
# 3           Not targeted                  100               1000.0
# 4           Not targeted                  100               1000.0

# %%
# ===========
google_geo_spend = pd.read_csv("google-political-ads-transparency-bundle/google-political-ads-geo-spend.csv")
google_geo_spend = google_geo_spend.iloc[:,:4]
google_geo_spend.to_csv(google_dir_path + "google-political-ads-geo-spend.csv", index = False)
google_geo_spend.head()
# Out:
#   Country Country_Subdivision_Primary Country_Subdivision_Secondary  Spend_USD
# 0      AT                         NaN                           NaN    1110000
# 1      BE                         NaN                           NaN     439600
# 2      BG                         NaN                           NaN      10900
# 3      CY                         NaN                           NaN       7100
# 4      CZ                         NaN                           NaN      60600

# %%
# ===========
google_top_keywords = pd.read_csv("google-political-ads-transparency-bundle/google-political-ads-top-keywords-history.csv")
google_top_keywords.to_csv(google_dir_path + "google-political-ads-top-keywords-history.csv", index = False)
google_top_keywords.head()
# Out:
#     Election_Cycle Region   Elections Report_Date         Keyword_1  \
# 0  US-Federal-2018     US  US-Federal  2019-12-02  elizabeth warren
# 1  US-Federal-2018     US  US-Federal  2019-11-25  elizabeth warren
# 2  US-Federal-2018     US  US-Federal  2019-11-20  elizabeth warren
# 3  US-Federal-2018     US  US-Federal  2019-11-18  elizabeth warren
# 4  US-Federal-2018     US  US-Federal  2019-11-11  elizabeth warren
#
#    Spend_USD_1       Keyword_2  Spend_USD_2      Keyword_3  Spend_USD_3  \
# 0      1491100  pete buttigieg      1403700  kamala harris       964900
# 1      1479900  pete buttigieg      1379200  kamala harris       964300
# 2      1469600  pete buttigieg      1312100  kamala harris       962900
# 3      1466600  pete buttigieg      1286400  kamala harris       962800
# 4      1452300  pete buttigieg      1209500  kamala harris       962200
#
#        Keyword_4  Spend_USD_4      Keyword_5  Spend_USD_5      Keyword_6  \
# 0  tulsi gabbard       742800   donald trump       727400  beto o rourke
# 1  tulsi gabbard       715100   donald trump       685900  beto o rourke
# 2  tulsi gabbard       692300  beto o rourke       673300   donald trump
# 3  tulsi gabbard       690300  beto o rourke       673300   donald trump
# 4  tulsi gabbard       681000  beto o rourke       673300   donald trump
#
#    Spend_USD_6
# 0       673300
# 1       673300
# 2       665300
# 3       659100
# 4       628800
